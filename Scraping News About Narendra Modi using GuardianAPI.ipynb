# %%
import pandas as pd
import requests

# %%
API_KEY="4c043d21-d53e-4a99-a6f3-1a08745b7575"

# %%
url="https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=4c043d21-d53e-4a99-a6f3-1a08745b7575&type=article&page=1"

# %%
urllist=[]

# %%
for i in range(1,12):
    a="https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=4c043d21-d53e-4a99-a6f3-1a08745b7575&type=article&page="
    b=str(i)
    c=a+b
    urllist.append(c)

# %%
urllist
# Out:
# ['https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=4c043d21-d53e-4a99-a6f3-1a08745b7575&type=article&page=1',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=4c043d21-d53e-4a99-a6f3-1a08745b7575&type=article&page=2',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=4c043d21-d53e-4a99-a6f3-1a08745b7575&type=article&page=3',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=4c043d21-d53e-4a99-a6f3-1a08745b7575&type=article&page=4',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=4c043d21-d53e-4a99-a6f3-1a08745b7575&type=article&page=5',
#  'https://content.guardianapis.com/world/narendra-modi?from-date=2021-01-01&api-key=4c043d21-d53e-4a99-a6f3-1a08745b7575&type=article&page=6',
# ...

# %%
info=[]

# %%
def json(url1):
    response=requests.get(url1)
    x=response.json()
    info.append(x)

# %%
output=[json(url1) for url1 in urllist]

# %%
info[9]['response']['results'][9]['webTitle']
# Out:
# 'The darkest hour- India’s Covid crisis: Inside the 7 May Guardian Weekly'

# %%
finallist=[]

# %%
try:
    for k in range(0,11):
        for j in range(0,10):
            value=dict(webtitle=info[k]['response']['results'][j]['webTitle'],
        sectionname=info[k]['response']['results'][j]['sectionName'],
        publisheddate=info[k]['response']['results'][j]['webPublicationDate'])
            finallist.append(value)
except IndexError:
    print("done")

# %%
datanew=pd.DataFrame(finallist)
datanew
# Out:
#                                               webtitle sectionname  \
# 0    Rahul Gandhi could face jail and loss of seat ...  World news
# 1    Indian government agency investigates BBC over...       Media
# 2    India’s Rahul Gandhi fights ‘excessive’ defama...  World news
# 3    Indian government accused of rewriting history...  World news
# 4    Twitter accused of censorship in India as it b...  World news
# ..                                                 ...         ...
# 105  Facebook blocked hashtag calling for Narendra ...  Technology
# 106  Vaccine hoarding is all the more disturbing as...     Opinion
# 107  US and UK lead global efforts to help India’s ...  World news
# 108  The Guardian view on Modi’s mistakes: a pandem...      Global
# 109  India's government has abandoned its citizens ...     Opinion
#
#             publisheddate
# 0    2023-04-20T05:51:29Z
# 1    2023-04-13T10:35:51Z
# 2    2023-04-09T19:37:52Z
# 3    2023-04-06T09:54:38Z
# ...

# %%
info
# Out:
# [{'response': {'status': 'ok',
#    'userTier': 'developer',
#    'total': 128,
#    'startIndex': 1,
#    'pageSize': 10,
#    'currentPage': 1,
#    'pages': 13,
#    'orderBy': 'newest',
#    'tag': {'id': 'world/narendra-modi',
#     'type': 'keyword',
#     'sectionId': 'world',
#     'sectionName': 'World news',
#     'webTitle': 'Narendra Modi',
#     'webUrl': 'https://www.theguardian.com/world/narendra-modi',
#     'apiUrl': 'https://content.guardianapis.com/world/narendra-modi'},
#    'results': [{'id': 'world/2023/apr/20/rahul-gandhi-facing-jail-and-loss-of-parliamentary-seat-after-indian-court-rejects-plea',
#      'type': 'article',
#      'sectionId': 'world',
#      'sectionName': 'World news',
#      'webPublicationDate': '2023-04-20T05:51:29Z',
#      'webTitle': 'Rahul Gandhi could face jail and loss of seat after Indian court rejects plea',
# ...
